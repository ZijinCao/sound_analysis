# %% [markdown]
# <a href="https://colab.research.google.com/github/ZijinCao/sound_analysis/blob/main/freesound_json_csv.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install git+https://github.com/MTG/freesound-python
# Out:
# Collecting git+https://github.com/MTG/freesound-python
#   Cloning https://github.com/MTG/freesound-python to /tmp/pip-req-build-16d339sr
#   Running command git clone --filter=blob:none --quiet https://github.com/MTG/freesound-python /tmp/pip-req-build-16d339sr
#   Resolved https://github.com/MTG/freesound-python to commit 5be99a3689d17303c01cb122bbb0d5a96eba04f6
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests<3.0,>2.27 in /usr/local/lib/python3.10/dist-packages (from freesound-python==1.1) (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0,>2.27->freesound-python==1.1) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0,>2.27->freesound-python==1.1) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0,>2.27->freesound-python==1.1) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0,>2.27->freesound-python==1.1) (2024.2.2)

# %%
import requests
import os
import json
import pandas as pd
from tqdm import tqdm
from google.colab import files
from requests_oauthlib import OAuth2Session
from freesound import FreesoundClient
import time

CLIENT_ID = 'z85PmZwVLBZvJrl8IuWc'
API_KEY = 'psSddwaXUW1fVd39QphtzWqU7JxwRfahhBHodVs7'

# Set up the Freesound client
client = FreesoundClient()
client.set_token(API_KEY, "token")

# Specify the desired query and fields
query = ["cold"]
fields = "id,name,previews,tags,analysis"

# Specify the number of sounds to analyze
total_sounds_to_analyze = 400

# Counter for analyzed sounds
analyzed_sounds = 0

# Counter for current page
current_page = 1

# List to store results
results_list = []

# Loop until the desired number of sounds is analyzed
with tqdm(total=total_sounds_to_analyze, desc="Analyzing sounds") as pbar:
    while analyzed_sounds < total_sounds_to_analyze:
        try:
            # Perform a text search for the query with specified fields and page
            results = client.text_search(query=query, fields=fields, page=current_page)

            # Loop through the results and get analysis for each sound
            for sound in results:
                try:
                    # Get the preview link directly from the API
                    mp3_link = sound.previews.preview_lq_mp3 if hasattr(sound.previews, 'preview_lq_mp3') else None

                    # Get the analysis for the sound with retries
                    retry_count = 0
                    max_retries = 3
                    while retry_count < max_retries:
                        try:
                            analysis = sound.get_analysis()
                            break
                        except Exception as e:
                            retry_count += 1
                            time.sleep(3)  # Wait for 3 second before retrying

                    # Convert the analysis to a dictionary
                    analysis_dict = analysis.as_dict() if analysis else None

                    # Include additional sound information
                    sound_info = {
                        "query": query,
                        "id": sound.id,
                        "name": sound.name,
                        "previews": mp3_link,
                        "tags": sound.tags,
                        "analysis": analysis_dict,
                        # Include other fields as needed
                    }

                    # Append the dictionary to the results list
                    results_list.append(sound_info)

                    # Increment the counters
                    analyzed_sounds += 1
                    pbar.update(1)

                    # If the desired number of sounds is analyzed, break out of the loop
                    if analyzed_sounds >= total_sounds_to_analyze:
                        break

                except Exception as e:
                    print(f"Warning: Error analyzing sound with ID {sound.id}. {e}")
                    continue

            # Increment the page counter for the next request
            current_page += 1
            # Introduce a longer delay to avoid hitting the rate limit
            time.sleep(2)

        except Exception as e:
            # Handle the case where no more sounds are found
            if "Rate limit exceeded" in str(e):
                print("Rate limit exceeded. Waiting for 60 seconds before retrying.")
                time.sleep(60)  # Wait for 60 seconds before retrying
                continue
            else:
                print(f"Warning: Only {analyzed_sounds} sounds found. {e}")
                break

# Specify the JSON file name
json_file = f"{query}.json"

# Write the results to the JSON file
with open(json_file, mode="w", encoding="utf-8") as file:
    json.dump(results_list, file, indent=2, default=str)  # Use default=str to handle non-serializable types

# Download the file to the local machine
files.download(json_file)
# Out:
# Analyzing sounds:   4%|▍         | 15/400 [01:59<51:11,  7.98s/it]
# Warning: Only 15 sounds found. <FreesoundException: code=429, detail="Too Many Requests">

# %%
# This is the previous code. Do not run this.

"""
import requests
import os
import json
import pandas as pd
from tqdm import tqdm
from google.colab import files
from requests_oauthlib import OAuth2Session
from freesound import FreesoundClient
import time

CLIENT_ID = 'V5cdp0WGbECF2c4VIc3E'
API_KEY = 'O7kpuZ3RPzzFvXv1eULaxi2SHvA6awM6Roxwk0C3'

# Set up the Freesound client
client = FreesoundClient()
client.set_token(API_KEY, "token")

# Specify the desired query and fields
query = ["bright", "dark"]
fields = "id,name,previews,tags,analysis"

# Specify the number of sounds to analyze
total_sounds_to_analyze = 200

# Counter for analyzed sounds
analyzed_sounds = 0

# Counter for current page
current_page = 1

# List to store results
results_list = []

# Loop until the desired number of sounds is analyzed
with tqdm(total=total_sounds_to_analyze, desc="Analyzing sounds") as pbar:
    while analyzed_sounds < total_sounds_to_analyze:
        try:
            # Perform a text search for the query with specified fields and page
            results = client.text_search(query=query, fields=fields, page=current_page)

            # Loop through the results and get analysis for each sound
            for sound in results:
                try:
                    # Get the preview link directly from the API
                    mp3_link = sound.previews.preview_lq_mp3 if hasattr(sound.previews, 'preview_lq_mp3') else None

                    # Get the analysis for the sound with retries
                    retry_count = 0
                    max_retries = 3
                    while retry_count < max_retries:
                        try:
                            analysis = sound.get_analysis()
                            break
                        except Exception as e:
                            retry_count += 1
                            time.sleep(1)  # Wait for 1 seconds before retrying

                    # Convert the analysis to a dictionary
                    analysis_dict = analysis.as_dict() if analysis else None

                    # Include additional sound information
                    sound_info = {
                        "query": query,
                        "id": sound.id,
                        "name": sound.name,
                        "previews": mp3_link,
                        "tags": sound.tags,
                        "analysis": analysis_dict,
                        # Include other fields as needed
                    }

                    # Append the dictionary to the results list
                    results_list.append(sound_info)

                    # Increment the counters
                    analyzed_sounds += 1
                    pbar.update(1)

                    # If the desired number of sounds is analyzed, break out of the loop
                    if analyzed_sounds >= total_sounds_to_analyze:
                        break

                except Exception as e:
                    print(f"Warning: Error analyzing sound with ID {sound.id}. {e}")
                    continue

            # Increment the page counter for the next request
            current_page += 1
            # Introduce a delay to avoid hitting the rate limit
            time.sleep(1)

        except Exception as e:
            # Handle the case where no more sounds are found
            print(f"Warning: Only {analyzed_sounds} sounds found. {e}")
            break

# Specify the JSON file name
json_file = f"{query}.json"

# Write the results to the JSON file
with open(json_file, mode="w", encoding="utf-8") as file:
    json.dump(results_list, file, indent=2, default=str)  # Use default=str to handle non-serializable types

# Download the file to the local machine
files.download(json_file)
"""

# %%
import pandas as pd

# Load the JSON file into a Pandas DataFrame
df = pd.read_json(json_file)

# Flatten the nested JSON entries under the "analysis" column
df_analysis = pd.json_normalize(df['analysis'])

# Concatenate the flattened analysis DataFrame with the original DataFrame
df = pd.concat([df, df_analysis], axis=1)

# Drop the original "analysis" column
df = df.drop('analysis', axis=1)

# Assume query is the string variable for the output CSV file
csv_file_path = f"{query}_output.csv"

# Export the DataFrame to a CSV file
df.to_csv(csv_file_path, index=False)

# Download the CSV file to the local machine
files.download(csv_file_path)


df.head()
# Out:
#     query      id                           name  \
# 0  [dull]  119870                 dull metal.aif
# 1  [dull]   89433                  DULL_Kick.wav
# 2  [dull]  508480            water-plop-dull.wav
# 3  [dull]  533579        dull kick 2020 4 19.wav
# 4  [dull]   87984  Cutting-carrot_dull-knife.aif
#
#                                             previews  \
# 0  https://cdn.freesound.org/previews/119/119870_...
# 1  https://cdn.freesound.org/previews/89/89433_14...
# 2  https://cdn.freesound.org/previews/508/508480_...
# 3  https://cdn.freesound.org/previews/533/533579_...
# 4  https://cdn.freesound.org/previews/87/87984_11...
#
#                                                 tags  \
# 0                                      [dull, metal]
# 1                                  [beat, bit, dull]
# 2  [bubbling, flap, liquid, drop, aqua, bubble, d...
# 3  [perc, one-shot, drum, synth, percussion, bass...
# 4   [board, carrot, cutting, dull, knife, vegetable]
#
#    lowlevel.spectral_complexity.min  lowlevel.spectral_complexity.max  \
# 0                               0.0                          5.000001
# 1                               0.0                         25.000001
# 2                               0.0                          8.000000
# 3                               0.0                         13.999999
# 4                               0.0                         48.000000
#
#    lowlevel.spectral_complexity.dvar2  lowlevel.spectral_complexity.dmean2  \
# 0                            0.380698                             0.077336
# 1                            8.408159                             2.142857
# 2                           11.875430                             1.647059
# 3                            5.392858                             1.500000
# 4                           72.604032                             2.413519
#
#    lowlevel.spectral_complexity.dmean  ...  rhythm.second_peak_bpm.max  \
# 0                            0.038627  ...                  102.999992
# 1                            3.125000  ...                    0.000000
# 2                            0.888889  ...                    0.000000
# 3                            1.133333  ...                    0.000000
# 4                            1.488095  ...                  105.000007
#
#    rhythm.second_peak_bpm.min  rhythm.second_peak_bpm.mean  rhythm.onset_rate  \
# 0                  102.999992                   102.999992           3.602338
# 1                    0.000000                     0.000000           5.066636
# 2                    0.000000                     0.000000           2.327914
# 3                    0.000000                     0.000000           2.778478
# 4                  105.000007                   105.000007           1.792655
#
#                                rhythm.beats_position  \
# 0  [0.5340589284896851, 1.09133780002594, 1.61378...
# 1                                                 []
# 2                                                 []
# 3                                                 []
# 4  [0.5340589284896851, 1.102947831153869, 1.6486...
#
#    rhythm.first_peak_weight.max  rhythm.first_peak_weight.min  \
# 0                      0.216216                      0.216216
# 1                      0.000000                      0.000000
# 2                      0.000000                      0.000000
# 3                      0.000000                      0.000000
# 4                      0.235294                      0.235294
#
#    rhythm.first_peak_weight.mean  metadata.version.essentia  \
# 0                       0.216216                  2.1-beta1
# 1                       0.000000                  2.1-beta1
# 2                       0.000000                  2.1-beta1
# 3                       0.000000                  2.1-beta1
# 4                       0.235294                  2.1-beta1
#
#    metadata.version.freesound_extractor
# 0                                   0.3
# 1                                   0.3
# 2                                   0.3
# 3                                   0.3
# 4                                   0.3
#
# [5 rows x 459 columns]
